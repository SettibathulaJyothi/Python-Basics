# %% [markdown]
# <a href="https://colab.research.google.com/github/SettibathulaJyothi/Python-Basics/blob/main/Image_processing_Operations_OpenCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Image Processing Operations**
# Some of the fuctions we can perform over images:

# %%
import cv2
img=cv2.imread('Flower.jpeg')
print(img.shape)
# Out:
# (388, 515, 3)

# %%
img=cv2.imread('Flower.jpeg')
print(img.min())
print(img.max())
# Out:
# 0
# 255

# %%
import cv2 #import CV
from matplotlib import pyplot as plt
import numpy as np
img=cv2.imread('Flower.jpeg')
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
plt.axis('on')
plt.title('RGB-Display')
plt.show()
print(img.shape)
[B,G,R]=img[25,40]
print('Red=',R,'Green',G,'Blue',B)
# Out:
# (388, 515, 3)
# Red= 22 Green 67 Blue 38

# %%
import cv2 #import CV
from matplotlib import pyplot as plt
import numpy as np
img=cv2.imread('Flower1.jpeg')
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
plt.axis('on')
plt.title('RGB-Display')
plt.show()
print(img.shape)
[B,G,R]=img[25,40]
print('Red=',R,'Green',G,'Blue',B)
# Out:
# (447, 447, 3)
# Red= 88 Green 76 Blue 50

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
img=cv2.imread('Flower.jpeg')
roi=img[135:365,115:350] #roi(region of interest)
plt.imshow(cv2.cvtColor(roi,cv2.COLOR_BGR2RGB))
plt.title('Flower.jpeg')
plt.axis('off')
plt.show()

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
img=cv2.imread('Flower1.jpeg')
roi=img[135:365,115:350] #roi(region of interest)
plt.imshow(cv2.cvtColor(roi,cv2.COLOR_BGR2RGB))
plt.title('Flower.jpeg')
plt.axis('off')
plt.show()
