# %% [markdown]
# <a href="https://colab.research.google.com/github/SettibathulaJyothi/Python-Basics/blob/main/looping_statements.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for count in [1,2,3,4,5]:
  print(count)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for friends in ["Anu","Ritu","All","Sonia"]:
  print(friends)
# Out:
# Anu
# Ritu
# All
# Sonia

# %%
for vowels in "AEIOU":
  print(vowels)
# Out:
# A
# E
# I
# O
# U

# %% [markdown]
# Using **range** function

# %%
for count in range(1,5,1):
  print("Welcome")
print("Iteration Finished")
# Out:
# Welcome
# Welcome
# Welcome
# Welcome
# Iteration Finished

# %%
for A in range(1,11,2):
  print(A,end=",")
# Out:
# 1,3,5,7,9,

# %%
for var in range(100,10,-10):
  print(var,end=",")
# Out:
# 100,90,80,70,60,50,40,30,20,

# %%
for var in range(5,10,2):
  print(var,end=",")
# Out:
# 5,7,9,
