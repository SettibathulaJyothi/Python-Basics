# %% [markdown]
# <a href="https://colab.research.google.com/github/SettibathulaJyothi/Python-Basics/blob/main/Python_Practical_Questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Python Practical Questions:**
#
# **1.Write a program to add the elements  of the two lists.**

# %%
S1 = [32, 45, 40]
S2 = [35, 30, 42, 38]
print("*** List S1 ***")
print(S1, len(S1))
print("*** List S2 ***")
print(S2, len(S2))
All = S1 + S2
print("*** List All ***")
print(All, len(All))
# Out:
# *** List S1 ***
# [32, 45, 40] 3
# *** List S2 ***
# [35, 30, 42, 38] 4
# *** List All ***
# [32, 45, 40, 35, 30, 42, 38] 7

# %% [markdown]
# **2.Write a program to calculate mean, meadian and mode using Numpy of the following list of distance travelled by a car in a week:**

# %%
import statistics
d = [95,90,49,71,90,100,55]
m1=statistics.mean (d)
m2=statistics.median(d)
m3=statistics.mode (d)
print("The mean is: ", m1)
print("The median is: ", m2)
print("The mode is: ", m3)
# Out:
# The mean is:  78.57142857142857
# The median is:  90
# The mode is:  90

# %% [markdown]
# **3.Write a python code to take the input of a number n and then find and display its factorial(n!).For example,5!=5x4x3x2x1 i.e.,120**

# %%
n=int(input("Enter a number: "))
factorial = 1
if n < 0:
  print("Factorial does not exist for negative numbers")
elif n == 0:
  print("The factorial of 0 is 1")
else:
  for i in range (1, n + 1):
    factorial=factorial*i
print("The factorial of ",n," is", factorial)
# Out:
# Enter a number: 22
# The factorial of  22  is 1124000727777607680000

# %% [markdown]
# **4. Write a program to display line chart from (2,5) to (9,10).**

# %%
import matplotlib.pyplot as plt
import numpy as np
#Define X and y variable data
x=np.array([2,3,9,101])
y=x*2
plt.plot(x, y)
plt.xlabel("X-axis") # add x-axis label
plt.ylabel("y-axis") # add y-axis label
plt.title("Line Chart") #add title
plt.show()

# %% [markdown]
# **5.Write a program to display a scatter chart for the following points (2,5),(9,10),(8,3),(5,7),(6,18).**

# %%
import matplotlib.pyplot as plt
import numpy as np
(2,5),(9,10),(8,3),(5,7),(6,18)
x= np.array([2,9,8,5,6])
y= np.array([5,10,3,7,18])
plt.xlabel("X-axis") # add X-axis label
plt.ylabel("Y-axis") #add Y-axis label
plt.title("Scatter Chart") # add title
plt.scatter(x, y)
plt.show()

# %% [markdown]
# **6.Read CSV file saved in your system and display 10 rows.**

# %%
import pandas as pd
# Read the csv file
df=pd.read_csv('/heart.csv')
# Display the first 10 rows
print(df.head(10))
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
# 5   58    0   0       100   248    0        0      122      0      1.0      1
# 6   58    1   0       114   318    0        2      140      0      4.4      0
# 7   55    1   0       160   289    0        0      145      1      0.8      1
# 8   46    1   0       120   249    0        0      144      0      0.8      2
# 9   54    1   0       122   286    0        0      116      1      3.2      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# ...

# %% [markdown]
# **7.Read csv file saved in your system and display its information.**

# %%
import pandas as pd
#Read the CSV file
df=pd.read_csv('/heart.csv')
print (df)
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %% [markdown]
# **8.Write a program to input a string and display the string in the reverse order.**

# %%
def reverse_string(str):
  str1 =" "
  for i in str:
    str1 = i + str1
  return str1
str = "ArtificialIntelligence"
print("The original string is: ",str)
print("The reverse string is", reverse_string(str))
# Out:
# The original string is:  ArtificialIntelligence
# The reverse string is ecnegilletnIlaicifitrA

# %% [markdown]
# **9.Write a program to read an image and display using python library import cv2,matplotlib
# Upload an image of your favourite city in the world on the screen and give a proper title to it.**

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
img=cv2.imread('Israel.jpeg')
plt.imshow(img)
plt.title('My Favourite City:Israel')
plt.axis('off')
plt.show()

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
img=cv2.imread('London.jpeg')
plt.imshow(img)
plt.title('My Favourite City:London')
plt.axis('off')
plt.show()

# %% [markdown]
# **10.Write a program to read an image and identify its shape using python**

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
image=cv2.imread('Israel.jpeg')
height,width,channels=image.shape
print("Image Shape:")
print("Height:",height)
print("width:",width)
print("Number of channels:",channels)
# Out:
# Image Shape:
# Height: 365
# width: 547
# Number of channels: 3

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
image=cv2.imread('London.jpeg')
height,width,channels=image.shape
print("Image Shape:")
print("Height:",height)
print("width:",width)
print("Number of channels:",channels)
# Out:
# Image Shape:
# Height: 350
# width: 570
# Number of channels: 3

# %% [markdown]
# **11.Write a program to input a string and display the count of vowels and consonants in the string**

# %%
str=input("Please enter a string as you wish:")
vowels=0
consonants=0
for i in str:
  if i in 'aeiouAEIOU':
    vowels+=1
  else:
    consonants+=1
print("The number of vowels:",vowels)
print("The number of consonants:",consonants)
# Out:
# Please enter a string as you wish:Happy Learning
# The number of vowels: 4
# The number of consonants: 10

# %% [markdown]
# **12.Write Python code to input the lengths of the three sides of a triangle and display whether a triangle can be formed with the inputs or not.If  a triangle can be formed then display whether the triangle will be scalene,isosceles or equilateral triangle.**

# %%
print("Input the sides of the triangle:")
A=int(input("A: "))
B=int(input("B: "))
C=int(input("C: "))
if A==B==C:
  print("Equivalent triangle")
elif A==B or B==C or A==C:
  print("isosceles traingle")
else:
  print("Scalene triangle")
# Out:
# Input the sides of the triangle:
# A: 12
# B: 13
# C: 13
# isosceles traingle

# %% [markdown]
# **13.Write a program to input two numbers and display**

# %%
def calculate_lcm(x,y):
  if x>y:
    greater=x
  else:
    greater=y
  while(True):
    if((greater %x==0) and (greater % y==0)):
      lcm=greater
      break
    greater+=1
  return lcm
num1=int(input("Enter first number:"))
num2=int(input("Enter second number:"))
print("The LCM of",num1 ,"and",num2,"is",calculate_lcm(num1,num2))
# Out:
# Enter first number:56
# Enter second number:65
# The LCM of 56 and 65 is 3640

# %% [markdown]
# **14.Write a program to input a number and display whether it is a palindrome or not.**

# %%
num=int(input("Enter a number:"))
temp=num
rev=0
while(num>0):
  dig=num%10
  rev=rev*10+dig
  num=num//10
if(temp==rev):
  print("The number is a palindrome!")
else:
  print("The number is not a palindrome!")
# Out:
# Enter a number:235
# The number is not a palindrome!

# %%
num=int(input("Enter a number:"))
temp=num
rev=0
while(num>0):
  dig=num%10
  rev=rev*10+dig
  num=num//10
if(temp==rev):
  print("The number is a palindrome!")
else:
  print("The number is not a palindrome!")
# Out:
# Enter a number:12521
# The number is a palindrome!

# %% [markdown]
# **15.Write a program to input a number and display whether it is a prime number or not.**

# %%
num = int(input("Enter a number: "))
if num > 1:
    for i in range(2, int(num / 2) + 1):
        if (num % i) == 0:
            print(num, "is not a prime number")
            break
    else:
        print(num, "is a prime number")
else:
    print(num, "is not a prime number")
# Out:
# Enter a number: 65
# 65 is not a prime number

# %% [markdown]
# **16.Write a program to input two numbers and swap both the numbers without using the third number.**

# %%
x = int(input("Enter the value of x: "))
y = int(input("Enter the value of y: "))
print("Numbers before swapping: %d  %d\n" % (x, y))
x = x + y
y = x - y
x = x - y
print("Numbers after swapping: %d  %d\n" % (x, y))
# Out:
# Enter the value of x: 22
# Enter the value of y: 14
# Numbers before swapping: 22  14
#
# Numbers after swapping: 14  22

# %% [markdown]
# **17. Using Numpy Package:\
# a.Create a 4x2 array with random integer.\
# b.Create 3x3 array with all zeros.**

# %%
import numpy as np
array1=np.random.randint(0, 10, (4, 2))
print("4x2 Array with Random Integers:")
print (array1)
import numpy as np
array2=np.zeros((3, 3))
print("\n3x3 Array with Zeros:")
print(array2)
# Out:
# 4x2 Array with Random Integers:
# [[1 1]
#  [1 1]
#  [6 8]
#  [1 7]]
#
# 3x3 Array with Zeros:
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [0. 0. 0.]]

# %% [markdown]
# **18.Using Matplotlib and the given data, plot a bar chart:\
# No of people voted = [23,45,31,40,35]\
# Area covered = ['a1','a2','a3','a4','a5']**

# %%
import matplotlib.pyplot as plt
# Data for the chart
No_of_people_voted = [23, 45, 31, 40, 35]
# Creating the bar chart
plt.bar(['a1', 'a2', 'a3', 'a4', 'a5'], No_of_people_voted)
# Adding labels and title
plt.title('Bar Chart')
plt.xlabel('Area Covered')
plt.ylabel('No of People Voted')
# Displaying the chart
plt.show()

# %% [markdown]
# **19.Using Matplotlib and the given data, plot a line chart:**

# %%
import matplotlib.pyplot as plt
# Data from the problem
x_axis = [3, 4, 6, 2, 8]
y_axis = [9, 10, 8, 7, 6]
# Plotting the line chart
plt.plot(x_axis, y_axis)
# Adding labels for clarity
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Line Chart')
# Display the plot
plt.show()

# %% [markdown]
# **20.Using Matplotlib and the given data, Plot a pie chart: Data 145,23, 41, 78, 65)**

# %%
import matplotlib.pyplot as plt
# Data provided in the image
Data = [45, 23, 41, 78, 65]
# Create the figure and axis
fig, ax = plt.subplots()
# Plot the pie chart
# autopct='%1.2f%%' formats the values as percentages with 2 decimal places
ax.pie(Data, autopct='%1.2f%%')
# Ensure the pie is drawn as a circle
ax.axis('equal')
# Display the plot
plt.show()

# %% [markdown]
# **21.Using Matplotlib and the given data, plot a scatter chart.**

# %%
import matplotlib.pyplot as plt
# Given data
Height = [4.5, 5.2, 4.1, 3.5, 5]
Weight = [34, 41, 45, 56, 39]
# Create the scatter plot
plt.scatter(Height, Weight, c='blue')
# Add titles and labels
plt.title('Scatter plot')
plt.xlabel('Height')
plt.ylabel('Weight')
# Display the chart
plt.show()

# %% [markdown]
# **22.Using NumPy package: Create an array of 5 marks and display the average of all marks.**

# %%
import numpy as np
# Create an array of 5 marks
marks = np.array([85, 90, 78, 92, 88])
# Calculate the average
average = np.mean(marks)
# Display the results
print("Marks:", marks)
print("Average Mark:", average)
# Out:
# Marks: [85 90 78 92 88]
# Average Mark: 86.6

# %% [markdown]
# **23.Create a list of number of voting done in 6 areas and calculate using statistics module.\
# Standard deviation\
# Variance**

# %%
import statistics
votes = [58, 52, 49, 71, 44, 83]
std_dev = statistics.stdev(votes)
print("The standard deviation is:", round(std_dev, 2))
variance = statistics.variance(votes)
print("The variance is:", variance)
# Out:
# The standard deviation is: 14.79
# The variance is: 218.7

# %% [markdown]
# **24.Using the library: import cv2, matplotlib Upload an image of your favourite food and display the picture in RGB color mode.**

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
# Read the image from the specified path
img = cv2.imread('biryani.jpeg')
# Convert from BGR (OpenCV default) to RGB (Matplotlib default) and display
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
# Add a title and hide the axes
plt.title('My Favourite Food')
plt.axis('off')
# Show the plot
plt.show()

# %% [markdown]
# **25.Using the library: import cv2, matplotlib Upload an image of your favourite pet and display the picture in grayscale mode.**

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
# Load the image in grayscale (the 0 flag)
img = cv2.imread('hen.jpg', 0)
# Display the image using Matplotlib
plt.imshow(img, cmap='gray')
plt.title('My Pet')
plt.axis('off') # Hide the x and y axes
plt.show()

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
# Load the image in grayscale (the 0 flag)
img = cv2.imread('hen.jpg')
# Display the image using Matplotlib
img_rgb=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.title('My Pet')
plt.axis('off') # Hide the x and y axes
plt.show()

# %% [markdown]
# **26.Using the library: import cv2, matplotlib Upload your own picture in your favorite dress and put a black box on the face and the hands.**

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
# Load the image
img = cv2.imread('mypic.jpeg')
# Draw a black rectangle ONLY over the face area
# Format: img[ymin:ymax, xmin:xmax]
img[50:200, 250:400] = [0, 0, 0]   # Face area box
# Convert BGR (OpenCV default) to RGB (Matplotlib default)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# Display the image
plt.imshow(img_rgb)
plt.title('Shaded Face')
plt.axis('off')
plt.show()
