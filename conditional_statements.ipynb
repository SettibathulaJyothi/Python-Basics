# %% [markdown]
# <a href="https://colab.research.google.com/github/SettibathulaJyothi/Python-Basics/blob/main/conditional_statements.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Conditional Statements:**
# Examples of Conditional Statements are illustrated below.

# %%
age=int(input("Enter the age:"))
if age>18:
  print("Eligible for voting")
else:
  print("not eligible for voting")
# Out:
# Enter the age:18
# not eligible for voting

# %%
age=int(input("Enter the age:"))
if age>18:
  print("Eligible for voting")
else:
  print("not eligible for voting")
# Out:
# Enter the age:20
# Eligible for voting

# %%
Year=int(input("Enter the year:"))
if Year%4==0 or Year%100==0 and Year%400==0:
  print("Leap Year")
else:
  print("Not a Leap Year")
# Out:
# Enter the year:2004
# Leap Year

# %%
Year=int(input("Enter the year:"))
if Year%4==0 or Year%100==0 and Year%400==0:
  print("Leap Year")
else:
  print("Not a Leap Year")
# Out:
# Enter the year:2015
# Not a Leap Year
