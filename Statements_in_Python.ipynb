# %% [markdown]
# <a href="https://colab.research.google.com/github/SettibathulaJyothi/Python-Basics/blob/main/Statements_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Simple Statement
x=5

# %%
#MultiLine Statements using Parentheses
result=(11+15+148+
        154+87)

# %%
#MultiLine Statements using Brces{}(for dictionaries or sets)
my_dict={'name':'John',
         'age':30,
         'city':'New York'}

# %%
#MultiLine Statements using Square Brackets[](for lists)
my_list=[1,2,3,4,
         5,6,7,8]

# %%
#MultiLine Statements using Continuation Character(\)
result=11+15+148+\
154+87
