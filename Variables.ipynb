# %% [markdown]
# <a href="https://colab.research.google.com/github/SettibathulaJyothi/Python-Basics/blob/main/Variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Variables:**
# Variable is a name given to a memory location tho hold a specific value.Its just like a container that can hold any type of data that can be changed later in the program.\
# **Variable has**:<br>
# A __name__ that follows rules of identifier naming conventions and is case sensitive.\
# A __Value__ that canbe integer,float,string,boolean,etc.
# The following shows demonstartion with examples.

# %%
num=9
print(num)
# Out:
# 9

# %%
Fruit="orange"
print(Fruit)
# Out:
# orange

# %%
#Method 1
rollno=5
strength=10.5
name="Amitha"

# %%
#Method 2
rollno,strength,nmae=5,10.5,"Amitha"

# %%
#Method 3
marks1=marks2=marks3=45
