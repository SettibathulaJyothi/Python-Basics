# %% [markdown]
# <a href="https://colab.research.google.com/github/SettibathulaJyothi/Python-Basics/blob/main/Variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Variables:Its just like a container that can hold any type of data that can be changed later in the program.
a=9
print(a)
a="Orange"
print(a)
# Out:
# 9
# Orange

# %%
#Method 1
rollno=5
strength=10.5
name="Amita"

# %%
#Method 2
rollno, strength, name=5,10.5,"Amita"

# %%
#Method 3
marks1=marks2=marks3=45
