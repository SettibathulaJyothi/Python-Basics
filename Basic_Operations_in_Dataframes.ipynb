# %% [markdown]
# <a href="https://colab.research.google.com/github/SettibathulaJyothi/Python-Basics/blob/main/Basic_Operations_in_Dataframes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Basic operations in a DataFrame:**
# Some of the basic operations of DataFrame are as follows:

# %% [markdown]
# **Adding a new row**

# %%
import pandas as pd
d1={'Name': ['Riya','Sonali','Sneha'],'Marks':[92,90,89]}
f2=pd.DataFrame(d1,index=[11,22,33])
print(f2)
# Out:
#       Name  Marks
# 11    Riya     92
# 22  Sonali     90
# 33   Sneha     89

# %%
f2.loc[44]=['Nitin',84]
print(f2)
# Out:
#       Name  Marks
# 11    Riya     92
# 22  Sonali     90
# 33   Sneha     89
# 44   Nitin     84

# %% [markdown]
# **Adding a new column**

# %%
f2['section']=['A','E','E','C']
print(f2)
# Out:
#       Name  Marks section
# 11    Riya     92       A
# 22  Sonali     90       E
# 33   Sneha     89       E
# 44   Nitin     84       C

# %% [markdown]
# **Modifying an existing Row**

# %%
f2.loc[33]=['Sneha',95,'C']
print(f2)
# Out:
#       Name  Marks section
# 11    Riya     92       A
# 22  Sonali     90       E
# 33   Sneha     95       C
# 44   Nitin     84       C

# %% [markdown]
# **Deleting a Row**

# %%
f2=f2.drop(22,axis=0)
print(f2)
# Out:
#      Name  Marks section
# 11   Riya     92       A
# 33  Sneha     95       C
# 44  Nitin     84       C

# %% [markdown]
# **Deleting a Column**

# %%
f2=f2.drop('Marks',axis=1)
print(f2)
# Out:
#      Name section
# 11   Riya       A
# 33  Sneha       C
# 44  Nitin       C
