# %% [markdown]
# <a href="https://colab.research.google.com/github/SettibathulaJyothi/Python-Basics/blob/main/DataTypes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **DataTypes**

# %% [markdown]
#                           [Data Types]
#                               |
#     ----------------------------------------------------
#     ▼         ▼         ▼         ▼         ▼         ▼
#     Numbers     None     Boolean   Sequences  Sets    Maps
#     |                               |                   |
#     -------------------            ---------------      |
#     ▼         ▼       ▼             ▼      ▼     ▼   Dictionary
#     Integer   Float   Complex       String  List  Tuple

# %% [markdown]
# ![Datatypes.png](data:image/png;base64,...)

# %% [markdown]
# **The description of datatypes:**
# Numbers:Numeric value.It can be integer,float or complex.
# Integers:whole numbers(+ve,-ve,0) with no fraction or decimal value.Range of an integer inpython can be from-2147483648 to 2147483647,and long integer has unlimited range.

# %% [markdown]
# **Sequence:**
# It is a collection of data stored under a common name.

# %%
#Single line
" "
# Out:
# ' '

# %%
#Multi-Line String
'''It is
  an interesting
  Language'''
# Out:
# 'It is \n  an interesting\n  Language'

# %% [markdown]
# **List:**
# It is a sequence of heterogeneous value arranged as elements.

# %%
list_of_names=["Amit","Shweta","Peter","Zoya"]
Marks=[89,92,93,78,89]
Class10=[101,"Neha",89.5,102,"Shuseela",92]

# %% [markdown]
# **Tuples:**
# It is a sequence of heterogeneous values.

# %%
mytuple=("Amit","Sweta","Peter","John")
Marks=(89,92,93,78,89)
class10=(101,"Neha",8.9,102,"Shushil",92)

# %% [markdown]
# **Set:**
# A set is a collection of unique elements.

# %%
myset={21,52,33,54,95}

# %% [markdown]
# **Maps:**
# Maps are ordered datatypes used for mapping keys.
# **Dictionary:**
# It is a datatype that stores a collection of key:vlaue pairs

# %%
person={'name':'jyothi','Department':'sales'}
