# %% [markdown]
# <a href="https://colab.research.google.com/github/SettibathulaJyothi/Python-Basics/blob/main/Print_Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Print Function**
# Used to display an output on the screen

# %%
print("Good")
# Out:
# Good

# %%
print("Good" ,"Morning")
# Out:
# Good Morning

# %%
print("hi!"+"How are you")
# Out:
# hi!How are you

# %%
print("Trends","Following",sep="#",end="!")
# Out:
# Trends#Following!
